# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

activities = ['Studying', 'Playing', 'Watching TV', 'Sleeping']
time_spent = [3, 2, 2, 5]  # hours in a day

colors = ['skyblue', 'lightgreen', 'gold', 'lightcoral']

plt.figure(figsize=(6,6))
plt.pie(time_spent, labels=activities, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title("After School Activities")
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
 
days = [1, 2, 3, 4, 5, 6, 7]  # Days of the week
studying = [3, 4, 3, 5, 4, 3, 4]
playing = [2, 2, 1, 1, 2, 3, 2]
watching_tv = [2, 1, 2, 2, 1, 1, 1]
sleeping = [5, 5, 6, 5, 6, 5, 5]

# %%
labels = ['Studying', 'Playing', 'Watching TV', 'Sleeping']
colors = ['skyblue', 'lightgreen', 'gold', 'lightcoral']

# %%
plt.figure(figsize=(8,8))
plt.stackplot(days,studying,playing,watching_tv,sleeping,labels=labels,colors=colors,alpha=0.9)
plt.legend(loc="upper left")
plt.title("Student time table")
plt.xlabel("days")
plt.ylabel("hours")
plt.grid(True)

# %%
#assingment que
weeks=[1,2,3,4,5,6,7]
studying=[1,2,1,2,1,4,5]
games=[0,1,2,4,1,3,4]
sleeping=[8,8,8,8,8,10,10]
activites=["studying","playing","games","sleeping"]
plt.figure(figsize=(10,6))

colors = ['skyblue', 'lightgreen', 'gold', 'lightcoral']
plt.stackplot(weeks, studying, games, sleeping,
              labels=activites, colors=colors, alpha=0.8)
plt.legend(loc="upper left")
plt.xlabel('Day')
plt.ylabel('Hours')
plt.title('Weekly Activity')
# Out:
# Text(0.5, 1.0, 'Weekly Activity')
